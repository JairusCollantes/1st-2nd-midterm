# %%
import pandas as gyat
import hvplot.pandas as gyatt

df = gyat.read_csv("covid.csv")

df[["Country/Region","Confirmed","Deaths", "Recovered"]]
# Out:
# %opts magic unavailable (pyparsing cannot be imported)
# %compositor magic unavailable (pyparsing cannot be imported)
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='ac125577-d445-4194-83aa-884fa0782dc6'>
#   <div id="f94956fd-07c5-4e43-b695-f68c24b945c5" data-root-id="ac125577-d445-4194-83aa-884fa0782dc6" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ## Question 1
#
# ### Which country has the highest confirmed cases

# %%
df.sort_values(by = "Deaths", ascending = False)[["Country/Region", "Confirmed"]].head(1)
# Out:
#     Country/Region  Confirmed
# 173             US    4290259

# %% [markdown]
# ## Question 2
#
# ### Which country has the highest deaths

# %%
df.sort_values(by = "Deaths", ascending = False)[["Country/Region", "Deaths"]].head(1)
# Out:
#     Country/Region  Deaths
# 173             US  148011

# %% [markdown]
# ## Question 3
#
# ### Show Philippines Confirmed , Deaths , Recovered

# %%
df[df["Country/Region"] == "Philippines"][["Country/Region", "Confirmed", "Deaths", "Recovered"]]
# Out:
#     Country/Region  Confirmed  Deaths  Recovered
# 133    Philippines      82040    1945      26446

# %% [markdown]
# ## Question 4
#
# ### Display Per WHO Region

# %%
df.groupby("WHO Region")[["Confirmed", "Deaths", "Recovered"]].sum()
# Out:
#                        Confirmed  Deaths  Recovered
# WHO Region
# Africa                    723207   12223     440645
# Americas                 8839286  342732    4468616
# Eastern Mediterranean    1490744   38339    1201400
# Europe                   3299523  211144    1993723
# South-East Asia          1835297   41349    1156933
# Western Pacific           292428    8249     206770

# %% [markdown]
# ## Question 5
#
# ### What is the average Deaths per WHO region

# %%
df.groupby("WHO Region")[["Deaths"]].mean().round(2)
# Out:
#                         Deaths
# WHO Region
# Africa                  254.65
# Americas               9792.34
# Eastern Mediterranean  1742.68
# Europe                 3770.43
# South-East Asia        4134.90
# Western Pacific         515.56

# %% [markdown]
# ## HVPLOT 1
#
# ### Total cases per WHO region

# %%
contint = df.groupby("WHO Region")[["Confirmed", "Deaths", "Recovered", "Active"]].sum()
contint["Confirmed"].hvplot.bar(title = "Total Confirmed Cases by WHO Region", ylabel = "Total Confirmed Cases", rot = 45)
# Out:
# :Bars   [WHO Region]   (Confirmed)

# %% [markdown]
# ## HVPLOT 2
#
# ### confirmed and deaths

# %%
contint[["Confirmed","Deaths"]].hvplot.line(title = "Confirmed Cases VS Deaths per WHO region",xlabel = "WHO region", ylabel = "Number of Cases")
# Out:
# :NdOverlay   [Variable]
#    :Curve   [WHO Region]   (value)

# %% [markdown]
# ## HVPLOT 3
#
# ### Confirmed and deaths relationship

# %%
df.hvplot.scatter(x="Confirmed",y="Deaths",title="Confirmed vs Deaths Relationship"
)
# Out:
# :Scatter   [Confirmed]   (Deaths)

# %% [markdown]
# ## HVPLOT 4
#
# ### Total Active cases per WHO region

# %%
contint[["Confirmed","Recovered","Deaths"]].hvplot.area(stacked=True,title="COVID Case Distribution per WHO Region")
# Out:
# :NdOverlay   [Variable]
#    :Area   [WHO Region]   (value,Baseline)

# %% [markdown]
# ## HVPLOT 5
#
# ### Top 10 country with highest confirmed cases

# %%
df.sort_values("Confirmed", ascending=False).head(10).hvplot.barh(x="Country/Region",y="Confirmed",title="Top 10 Countries by Confirmed Cases")
# Out:
# :Bars   [Country/Region]   (Confirmed)
